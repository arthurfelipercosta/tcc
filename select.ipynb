# %%
import pandas as pd

# %%
# Caminho para o seu arquivo CSV
caminho_arquivo = 'projeto-busca-carros/dados_corrigidos_sem_duplicatas.csv'

# %%
# Nome da coluna que você quer verificar
# !! ATENÇÃO !! Substitua 'Nome_da_Coluna' pelo nome real da coluna que você deseja inspecionar
nome_da_coluna = 'Modelo'

# %%
try:
    # Carregar o arquivo CSV para um DataFrame do pandas
    df = pd.read_csv(caminho_arquivo, delimiter=';')

    # Verificar se a coluna existe no DataFrame
    if nome_da_coluna in df.columns:
        # Obter os valores únicos da coluna
        valores_unicos = df[nome_da_coluna].unique()

        # Exibir os valores únicos
        print(f"Opções na coluna '{nome_da_coluna}':")
        for valor in valores_unicos:
            print(valor)
    else:
        print(f"Erro: A coluna '{nome_da_coluna}' não foi encontrada no arquivo.")
        print("Colunas disponíveis:")
        print(df.columns.tolist())

except FileNotFoundError:
    print(f"Erro: O arquivo '{caminho_arquivo}' não foi encontrado.")
except Exception as e:
    print(f"Ocorreu um erro ao ler o arquivo: {e}")
# Out:
# Opções na coluna 'Modelo':
# DOLPHIN MINI
# ICAR EQ1
# 500E
# MOBI
# e-JS1
# E-KWID
# ARGO
# HB20
# Cooper
# JCW
# E-208
# 208
# Sandero
# A3Sportback
# 118i
# DOLPHIN
# BOLT
# BOLT EUV
# ONIX
# ONIXPLUS
# SPIN
# CRONOS
# ORA03
# CITY
# CITYHATCH
# HR-V
# HR-V(mod.25)
# IONIQ
# TUCSON TURBO
# KONAHEV
# KONAEV
# HB20S
# e-JS4
# STONIC
# AMGA354MATIC
# A200AMGLINE
# Countryman
# Versa
# E2008
# Logan
# Zoe
# Mégane
# YARISHATCHBACK
# YARISSEDÃ
# EX30
# POLO
# VIRTUS
# A3Sedan
# 218i
# iX1
# iX2
# D1
# ARRIZO6
# CRUZE
# CIVICHYBRID
# ZR-V
# COMPASS
# NIRO
# UX250H
# GHIBLI
# AMGA35SD 4MATIC
# AMGGLA354M
# GLA200
# AMGA45S4MATIC
# LEAF
# Sentra
# COROLLACROSS
# COROLLAHB
# COROLLA
# C40
# EC40
# ID.4
# A4Sedan
# A4Sedan Quattro
# A5Sportback
# A5SportbackQuattro
# RS5Sportback
# RS6Avant
# Q5
# Q5TFSIe
# Q5Sportback TFSIe
# Q7
# Q8Sportback
# RSQ8
# Q8e-tron Sportback55
# Q8e-tron 55
# e-tron GT
# RSe-tron GT
# SQ8e-tron Sportback
# 420i
# 530e
# iX3
# IXxDrive40
# IXxDrive50
# 330e
# 320i
# i4
# i7
# iX
# i5
# HAN
# TAN
# SEAL
# KING
# EQUINOX
# Novo Territory
# Mustang Mach-E
# HAVAL H6
# ACCORDHYBRID
# e-J7
# I-PACE
# URUS
# ES300H
# RX500H (MY24)
# C200
# C300
# EQE300
# EQA250
# EQB 250
# EQC4004M
# AMGCLA354MATIC
# AMGGLB354M
# AMGEQS534M
# AMGCLA45S4M
# GLB200
# E300
# AMGGLE534M
# GLS4504M
# AMGGLC43
# AMGGLE63SCO
# EQS450
# AMGEQE53
# CLA200
# GLB2204M
# CLA250
# AMGCLA354M
# EQB 3504M
# EQE350
# EQS4504M
# AMGC63SEP
# MACAN
# RAV4H
# RAV4
# CAMRY
# TIGUAN
# ID.BUZZ
# JETTA
# TIGGO5X
# TRACKER
# C4CACTUS
# C3
# C3AIRCROSS
# FASTBACK
# PULSE
# CRETA
# RENEGADE
# Kicks
# 2008
# Kwid
# Kardian
# NIVUS
# T CROSS
# Q3
# Q3Sportback
# X1
# X2
# YUAN PLUS
# SONGPLUS(MY25)
# SONGPLUS
# TIGGO8
# TIGGO7
# SERES3
# CR-VHYBRID
# COMMANDER
# SPORTAGE
# NX350H
# LEVANTE
# EclipseCross
# 3008
# Captur
# Duster
# XC40
# EX40
# TAOS
# X4
# X6
# X3
# X5
# X7
# PALISADE
# E-PACE
# F-PACE
# GLC3004M
# GLE400D 4M
# GLE450D 4M
# CAYENNE
# CAYENNE(ProduçãoSemana18+/24)
# FORESTER
# XV
# XC60
# XC90
# XC60(MY25)
# XC90(MY25)
# JIMNYSIERRA
# TRAILBLAZER
# Bronco Sport
# GCHEROKEE
# WRANGLER
# RANGEROVER
# RANGEROVER SPORT
# EVOQUE
# DISCOVERYSPORT
# VELAR
# DISCOVERY
# DEFENDER 90
# DEFENDER 110
# DEFENDER 130
# AMGG634M
# G580EQ
# Pajero Sport
# SW4DIESEL 4X4
# CARNIVAL
# ET3
# JUMPY
# E-JUMPY
# JUMPER
# DUCATO
# FIORINO
# E-SCUDO
# SCUDO
# Transit
# HR
# EJV5.5
# BONGOK25004X4SC
# BONGOK25004X4
# 315CDI STREET
# Townstar
# EXPERT
# E-EXPERT
# PARTNER RAPID
# BOXER
# Master Bus
# Master ChassisCabine
# Master PROFurgão
# Master Furgão
# Kangoo
# MONTANA
# STRADA
# Oroch
# SAVEIRO
# S10
# SILVERADO
# TORO
# TITANO
# Maverick
# F150
# NovaRanger 4x4
# NovaRanger 4x2
# Ranger Raptor
# IEV330P
# GLADIATOR
# L200Triton
# L200Triton Sport
# Frontier
# CLASSIC
# RAMPAGE
# 1500
# HILUXDIESEL 4X4
# AMAROK
# M3
# M2
# CAMARO
# ROMA
# 296
# PUROSANGUE
# Mustang
# Novo Mustang
# CIVIC
# F-TYPE
# HURACAN
# AMGSL63SEP
# ARTURA
# BOXSTER
# BOXSTER (ProduçãoSemana12+/24)
# CAYMAN
# CAYMAN(ProduçãoSemana12+/24)
# 911
# PANAMERA
# TAYCAN

# %%
# Nome da coluna onde a alteração será feita
# !! ATENÇÃO !! Substitua 'Nome_da_Coluna_Para_Alterar' pelo nome real da coluna
nome_da_coluna_para_alterar = 'Categoria'

# %%
# O valor antigo a ser encontrado
valor_antigo = 'ExtraGrande'

# O novo valor para substituir o antigo
novo_valor = 'Extra Grande'

# %%
try:
    # Carregar o arquivo CSV para um DataFrame do pandas
    df = pd.read_csv(caminho_arquivo, delimiter=';')

    # Verificar se a coluna existe
    if nome_da_coluna_para_alterar in df.columns:
        # Contar quantas ocorrências do valor antigo existem antes da alteração
        contagem_antes = df[nome_da_coluna_para_alterar].astype(str).str.count(valor_antigo).sum()

        # Realizar a substituição na coluna especificada
        # O inplace=True modifica o DataFrame diretamente
        df[nome_da_coluna_para_alterar] = df[nome_da_coluna_para_alterar].replace(valor_antigo, novo_valor)

        # Contar quantas ocorrências do novo valor existem depois da alteração
        contagem_depois = df[nome_da_coluna_para_alterar].astype(str).str.count(novo_valor).sum()

        print(f"Substituição concluída na coluna '{nome_da_coluna_para_alterar}'.")
        print(f"Ocorrências de '{valor_antigo}' encontradas e substituídas: {contagem_antes}")
        print(f"Ocorrências de '{novo_valor}' após a substituição: {contagem_depois}")

        # --- Opção para visualizar as primeiras linhas do DataFrame modificado ---
        print("\nPrimeiras 5 linhas do DataFrame modificado:")
        print(df.head().to_markdown(index=False)) # Use to_markdown() para melhor visualização em notebooks

        # --- Opção para salvar o DataFrame modificado em um novo arquivo CSV ---
        # Para salvar, remova o comentário da linha abaixo
        df.to_csv(caminho_arquivo, index=False, sep=';')
        print(f"\nDataFrame modificado salvo em '{caminho_arquivo}'")

    else:
        print(f"Erro: A coluna '{nome_da_coluna_para_alterar}' não foi encontrada no arquivo.")
        print("Colunas disponíveis:")
        print(df.columns.tolist())

except FileNotFoundError:
    print(f"Erro: O arquivo '{caminho_arquivo}' não foi encontrado.")
except Exception as e:
    print(f"Ocorreu um erro: {e}")
# Out:
# Substituição concluída na coluna 'Categoria'.
# Ocorrências de 'ExtraGrande' encontradas e substituídas: 120
# Ocorrências de 'Extra Grande' após a substituição: 120
#
# Primeiras 5 linhas do DataFrame modificado:
# | Categoria    | Marca     | Modelo       | Versão        | Motor    | Tipo de Propulsão   | Transmissão   | Ar Condicionado   | Direção Assistida   | Combustível   | Poluentes(NMOG+NOx [mg/km])   | Poluentes(CO [mg/km])   | Poluentes(CHO [mg/km])   | Redução Relativa ao Limite   | Gás Efeito Estufa (Etanol [CO2 fóssil] [g/km])   | Gás Efeito Estufa (Gasolina ou Diesel [CO2 fóssil] [g/km])   | Gás Efeito Estufa (VEHP [CO2 fóssil] [g/km])   | Km - (Etanol[Cidade][km/l])   | Km - (Etanol[Estrada][km/l])   | Km - (Gasolina ou Diesel[Cidade][km/l])   | Km - (Gasolina ou Diesel[Estrada][km/l])   | Km - (Elétrico quando VE ou VEHP [Cidade][km/le])   | Km - (Elétrico quando VE ou VEHP [Estrada][km/le])   | Consumo Energético   | Autonomia modo Elétrico   | Classificação PBE (Comparação Relativa)   | Classificação PBE (Absoluta na Categoria)   | Selo CONPET de Eficiência Energética   |   Unnamed: 28 |
# |:-------------|:----------|:-------------|:--------------|:---------|:--------------------|:--------------|:------------------|:--------------------|:--------------|:------------------------------|:------------------------|:-------------------------|:-----------------------------|:-------------------------------------------------|:-------------------------------------------------------------|:-----------------------------------------------|:------------------------------|:-------------------------------|:------------------------------------------|:-------------------------------------------|:----------------------------------------------------|:-----------------------------------------------------|:---------------------|:--------------------------|:------------------------------------------|:--------------------------------------------|:---------------------------------------|--------------:|
# | Sub Compacto | BYD       | DOLPHIN MINI | GSEV          | Elétrico | Elétrico            | N.A.          | S                 | E                   | E             | 0                             | 0                       | 0                        | A                            | \                                                | 0                                                            | \                                              | \                             | \                              | \                                         | \                                          | 58,6                                                | 41,9                                                 | 0,41                 | 280                       | A                                         | A                                           | -                                      |           nan |
# | Sub Compacto | CAOACHERY | ICAR EQ1     | TEC           | Elétrico | Elétrico            | A-            | S                 | E                   | E             | ND                            | ND                      | ND                       | A                            | \                                                | -                                                            | \                                              | \                             | \                              | \                                         | \                                          | 50,8                                                | 38,6                                                 | 0,46                 | 198                       | A                                         | A                                           | -                                      |           nan |
# | Sub Compacto | FIAT      | 500E         | ICON          | Elétrico | Elétrico            | A-1           | S                 | E                   | E             | ND                            | ND                      | ND                       | A                            | \                                                | -                                                            | \                                              | \                             | \                              | \                                         | \                                          | 47,3                                                | 40,4                                                 | 0,46                 | 227                       | A                                         | A                                           | -                                      |           nan |
# | Sub Compacto | FIAT      | MOBI         | LIKE          | 1.0-8V   | Combustão           | M-5           | S                 | H                   | F             | 46                            | 225                     | 4                        | B                            | 0                                                | 93                                                           | \                                              | 9,6                           | 10,4                           | 13,5                                      | 15,0                                       | \                                                   | \                                                    | 1,50                 | \                         | E                                         | B                                           | -                                      |           nan |
# | Sub Compacto | FIAT      | MOBI         | TREKKING1.0MT | 1.0-8V   | Combustão           | M-5           | S                 | H                   | F             | 46                            | 225                     | 4                        | B                            | 1                                                | 93                                                           | \                                              | 9,6                           | 10,4                           | 13,5                                      | 15,0                                       | \                                                   | \                                                    | 1,50                 | \                         | E                                         | B                                           | -                                      |           nan |
#
# DataFrame modificado salvo em 'projeto-busca-carros/dados_corrigidos_modificados.csv'
