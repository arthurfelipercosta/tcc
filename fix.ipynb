# %%
import pandas as pd

# %%
df = pd.read_csv('projeto-busca-carros/dados_corrigidos.csv', sep=';')
duplicados = df[df.duplicated(keep=False)]

# %%
display(duplicados)
# Out:
#                           Categoria    Marca Modelo          Versão     Motor  \
# 115                           Médio  Hyundai  HB20S  PlatinumSafety  1.0-12VT
# 116                           Médio  Hyundai  HB20S    PlatinumPlus  1.0-12VT
# 118                           Médio  Hyundai  HB20S    PlatinumPlus  1.0-12VT
# 119                           Médio  Hyundai  HB20S  PlatinumSafety  1.0-12VT
# 459     Utilitário Esportivo Grande      BMW     X1     sDrive18iGP   1.5-12V
# 460     Utilitário Esportivo Grande      BMW     X1     sDrive18iGP   1.5-12V
# 526  Utilitário Esportivo Grande4x4      BMW     X4       xDrive30i   2.0-16V
# 527  Utilitário Esportivo Grande4x4      BMW     X4       xDrive30i   2.0-16V
# 531  Utilitário Esportivo Grande4x4      BMW     X3            M40i   3.0-24V
# 532  Utilitário Esportivo Grande4x4      BMW     X3            M40i   3.0-24V
# 533  Utilitário Esportivo Grande4x4      BMW     X4            M40i   3.0-24V
# ...

# %%
print(f"Existem {duplicados.shape[0]} linhas duplicadas.")
# Out:
# Existem 12 linhas duplicadas.

# %%
df_sem_duplicadas = df.drop_duplicates()

# %%
df_sem_duplicadas.to_csv('projeto-busca-carros/dados_corrigidos_sem_duplicatas.csv', sep=';', index=False)
